# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscar-V-R/datasciencecoursera/blob/main/Course%201%20-%20Part%204%20-%20Lesson%204%20-%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %%
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.6):
      print("\nReached 60% accuracy so cancelling training!")
      self.model.stop_training = True

mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

callbacks = myCallback()

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer=tf.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10, callbacks=[callbacks])

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Datos del cronograma
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

meses = ["Mes 1", "Mes 2", "Mes 3", "Mes 4", "Mes 5", "Mes 6", "Mes 7", "Mes 8"]

# Planificación de actividades (inicio, duración)
plan = [
    (0, 2),  # Reuniones iniciales y plan de trabajo
    (1, 2),  # Mapeo de actores y análisis de referencia
    (2, 1),  # Taller 1 (diagnóstico)
    (2, 3),  # Evaluación de políticas y condiciones
    (4, 1),  # Visita técnica a Perú*
    (4, 1),  # Taller 2*
    (4, 2),  # Diseño participativo de hoja de ruta
    (5, 2),  # Redacción final y validación institucional
    (7, 1),  # Evento final
    (7, 1)   # Informe de cierre
]

entregables = {
    0: "Producto 1",
    1: "Producto 2",
    3: "Producto 3",
    6: "Producto 4",
    9: "Producto 5"
}

# Crear la figura
fig, ax = plt.subplots(figsize=(12, 6))
bar_height = 0.5

for i, (start, duration) in enumerate(plan):
    ax.broken_barh([(start, duration)], (len(actividades)-1-i - bar_height/2, bar_height),
                   facecolors='tab:blue')
    if i in entregables:
        ax.text(start + duration/2, len(actividades)-1-i, entregables[i],
                va='center', ha='center', fontsize=8, color='white', fontweight='bold')

# Etiquetas y estilo
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(reversed(actividades))
ax.set_xticks(range(len(meses)))
ax.set_xticklabels(meses)
ax.set_xlim(0, 8)
ax.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Mostrar la imagen
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones (meses en los que ocurre cada actividad)
duraciones = [
    [1, 2],       # Producto 1
    [1, 2],       # Producto 2
    [2],          # Taller 1
    [3, 4, 5],    # Producto 3
    [4],          # -
    [5],          # Taller 2
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables asignados a actividades (por índice de actividad)
entregables = {
    0: "Producto 1",
    1: "Producto 2",
    3: "Producto 3",
    6: "Producto 4",
    9: "Producto 5"
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 6))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        ax.text(min(meses) - 0.5 + len(meses)/2, i, entregables[i],
                ha='center', va='center', color=label_color, fontsize=8, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=9)
ax.set_xticks(range(8))
ax.set_xticklabels([f"Mes {i+1}" for i in range(8)], fontsize=9)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones (meses en los que ocurre cada actividad)
duraciones = [
    [1, 2],       # Producto 1
    [1, 2],       # Producto 2
    [2],          # Taller 1
    [3, 4, 5],    # Producto 3
    [4],          # -
    [5],          # Taller 2
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables asignados a actividades (por índice de actividad)
entregables = {
    0: "Producto 1",
    1: "Producto 2",
    3: "Producto 3",
    6: "Producto 4",
    9: "Producto 5"
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 6))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        ax.text(min(meses) - 0.5 + len(meses)/2, i, entregables[i],
                ha='center', va='center', color=label_color, fontsize=8, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=9)
ax.set_xticks(range(8))
ax.set_xticklabels([f"Mes {i+1}" for i in range(8)], fontsize=9)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)
ax.set_title("Cronograma de actividades y entregables", fontsize=11, weight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones (meses en los que ocurre cada actividad)
duraciones = [
    [1, 2],       # Producto 1
    [1, 2],       # Producto 2
    [2],          # Taller 1
    [3, 4, 5],    # Producto 3
    [4],          # -
    [5],          # Taller 2
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables asignados a actividades (por índice de actividad)
entregables = {
    0: "Producto 1",
    1: "Producto 2",
    3: "Producto 3",
    6: "Producto 4",
    9: "Producto 5"
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 6))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        label = entregables[i]
        if i == 9:
            # Producto 5: desplazar a la izquierda para que encaje
            ax.text(min(meses) - 0.9, i, label, ha='left', va='center',
                    color=label_color, fontsize=8, fontweight='bold')
        else:
            ax.text(min(meses) - 0.5 + len(meses)/2, i, label, ha='center', va='center',
                    color=label_color, fontsize=8, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=9)
ax.set_xticks(range(8))
ax.set_xticklabels([f"Mes {i+1}" for i in range(8)], fontsize=9)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)
ax.set_title("")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks(range(8))
ax.set_xticklabels([f"Mes {i+1}" for i in range(8)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)
ax.set_title("")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0:

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks(range(8))
ax.set_xticklabels([f"Mes {i+1}" for i in range(8)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])  # Mostrar final de cada mes
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_ylabel("Actividad", fontsize=17, labelpad=15)
ax.set_xticks([i for i in range(1, 9)])  # Mostrar final de cada mes
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color,_

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])  # Mostrar final de cada mes
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica (y Taller 2*)
    [4],          # Taller 2* (se comparte visualmente con anterior)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    # Evitar dibujar doble barra para i=5 (Taller 2), que comparte con i=4
    if i == 5:
        continue
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Agregar manualmente ambos textos en la misma barra para i=4
ax.text(4 - 0.4, 4 - 0.15, "Visita técnica a

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4],          # Visita técnica (y Taller 2*)
    [4],          # Taller 2* (se comparte visualmente con anterior)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    # Evitar dibujar doble barra para i=5 (Taller 2), que comparte con i=4
    if i == 5:
        continue
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Agregar manualmente ambos textos en la misma barra para i=4
ax.text(4 - 0.4, 4 - 0.15, "Visita técnica a Perú*", color="white", fontsize=10, fontweight='bold')
ax.text(4 - 0.4, 4 + 0.15, "Taller 2*", color="white", fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])  # Mostrar final de cada mes
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (AJUSTE aplicado en índice 4)
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4, 5],       # Visita técnica (AJUSTADO para que sea igual a Taller 2)
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (AJUSTE aplicado en índice 4)
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1 (sin entregable)
    [3, 4, 5],    # Producto 3
    [4, 5],       # Visita técnica (AJUSTADO para que sea igual a Taller 2)
    [5],          # Taller 2 (sin entregable)
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar cada barra horizontal y etiquetas de productos
for i, meses in enumerate(duraciones):
    for mes in meses:
        ax.barh(i, 1, left=mes - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if posicion == "right":
            ax.text(max(meses) - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(min(meses) - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (solo 1 rectángulo de mes 4 a 5 → usamos tupla personalizada)
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1
    [3, 4, 5],    # Producto 3
    [(4, 2)],     # Visita técnica (1 rectángulo desde mes 4 con duración 2)
    [5],          # Taller 2
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, meses in enumerate(duraciones):
    for m in meses:
        if isinstance(m, tuple):
            start, length = m
            ax.barh(i, length, left=start - 1, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=m - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        start = meses[0][0] if isinstance(meses[0], tuple) else min(meses)
        end = start + (meses[0][1] - 1) if isinstance(meses[0], tuple) else max(meses)
        if posicion == "right":
            ax.te

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (solo 1 rectángulo de mes 4 a 5 → usamos tupla personalizada)
duraciones = [
    [1, 2],       # Producto 1
    [2],          # Producto 2
    [2],          # Taller 1
    [3, 4, 5],    # Producto 3
    [(4, 2)],     # Visita técnica (1 rectángulo desde mes 4 con duración 2)
    [5],          # Taller 2
    [5, 6],       # Producto 4
    [6, 7],       # -
    [7],          # -
    [8]           # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, meses in enumerate(duraciones):
    for m in meses:
        if isinstance(m, tuple):
            start, length = m
            ax.barh(i, length, left=start - 1, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=m - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        start = meses[0][0] if isinstance(meses[0], tuple) else min(meses)
        end = start + (meses[0][1] - 1) if isinstance(meses[0], tuple) else max(meses)
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (✅ Visita técnica como único bloque de mes 4 a 5)
duraciones = [
    [1, 2],          # Producto 1
    [2],             # Producto 2
    [2],             # Taller 1
    [3, 4, 5],       # Producto 3
    [(4, 1)],        # ✅ Visita técnica a Perú: solo un bloque del mes 4 a 5
    [5],             # Taller 2
    [5, 6],          # Producto 4
    [6, 7],          # -
    [7],             # -
    [8]              # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, bloques in enumerate(duraciones):
    for bloque in bloques:
        if isinstance(bloque, tuple):
            start, length = bloque
            ax.barh(i, length, left=start - 1, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=bloque - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if isinstance(bloques[0], tuple):
            start = bloques[0][0]
            end = start + bloques[0][1]
        else:
            start = min(bloques)
            end = max(bloques) + 1
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (✅ Visita técnica: un solo bloque de mes 4 a mes 5)
duraciones = [
    [1, 2],          # Producto 1
    [2],             # Producto 2
    [2],             # Taller 1
    [3, 4, 5],       # Producto 3
    [(4, 1)],        # ✅ Visita técnica: bloque desde mes 4 a mes 5
    [5],             # Taller 2
    [5, 6],          # Producto 4
    [6, 7],          # -
    [7],             # -
    [8]              # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, bloques in enumerate(duraciones):
    for bloque in bloques:
        if isinstance(bloque, tuple):
            start, length = bloque
            ax.barh(i, length, left=start, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=bloque - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if isinstance(bloques[0], tuple):
            start = bloques[0][0]
            end = start + bloques[0][1]
        else:
            start = min(bloques)
            end = max(bloques)
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes (✅ Visita técnica corregida y hoja de ruta extendida)
duraciones = [
    [1, 2],          # Producto 1
    [2],             # Producto 2
    [2],             # Taller 1
    [3, 4, 5],       # Producto 3
    [(4, 1)],        # Visita técnica: mes 4 a 5
    [5],             # Taller 2
    [5, 6, 7],       # ✅ Diseño hoja de ruta (extendido a mes 7)
    [6, 7],          # -
    [7],             # -
    [8]              # Producto 5
]

# Entregables con posición específica ('left' o 'right')
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, bloques in enumerate(duraciones):
    for bloque in bloques:
        if isinstance(bloque, tuple):
            start, length = bloque
            ax.barh(i, length, left=start, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=bloque - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if isinstance(bloques[0], tuple):
            start = bloques[0][0]
            end = start + bloques[0][1]
        else:
            start = min(bloques)
            end = max(bloques)
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Estilo del gráfico
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)
ax.set_xticks([i for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)
ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título "Actividad" sobre la primera barra
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],          # Producto 1
    [2],             # Producto 2
    [2],             # Taller 1
    [3, 4, 5],       # Producto 3
    [(4, 1)],        # Visita técnica: mes 4 a 5
    [5],             # Taller 2
    [5, 6, 7],       # Diseño hoja de ruta (extendido)
    [6, 7],          # -
    [7],             # -
    [8]              # Producto 5
]

# Entregables
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, bloques in enumerate(duraciones):
    for bloque in bloques:
        if isinstance(bloque, tuple):
            start, length = bloque
            ax.barh(i, length, left=start, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=bloque - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if isinstance(bloques[0], tuple):
            start = bloques[0][0]
            end = start + bloques[0][1]
        else:
            start = min(bloques)
            end = max(bloques)
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Eje Y
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)

# Eje X (meses) alineados con inicio de cada mes
ax.set_xticks([i - 0.5 for i in range(1, 9)])  # Centrado al inicio del mes
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)

ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Mover eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título del eje Y (sobre la primera barra)
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Actividades
actividades = [
    "Reuniones iniciales y plan de trabajo",
    "Mapeo de actores y análisis de referencia",
    "Taller 1 (diagnóstico)",
    "Evaluación de políticas y condiciones",
    "Visita técnica a Perú*",
    "Taller 2*",
    "Diseño participativo de hoja de ruta",
    "Redacción final y validación institucional",
    "Evento final de formalización (virtual)",
    "Informe de cierre"
]

# Duraciones por mes
duraciones = [
    [1, 2],
    [2],
    [2],
    [3, 4, 5],
    [(4, 1)],
    [5],
    [5, 6, 7],
    [6, 7],
    [7],
    [8]
]

# Entregables
entregables = {
    0: ("Producto 1", "left"),
    1: ("Producto 2", "left"),
    3: ("Producto 3", "right"),
    6: ("Producto 4", "right"),
    9: ("Producto 5", "left")
}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7.5))

# Colores
bar_color = "#2a9df4"
label_color = "white"

# Dibujar barras
for i, bloques in enumerate(duraciones):
    for bloque in bloques:
        if isinstance(bloque, tuple):
            start, length = bloque
            ax.barh(i, length, left=start, height=0.6, color=bar_color, edgecolor='white')
        else:
            ax.barh(i, 1, left=bloque - 1, height=0.6, color=bar_color, edgecolor='white')
    if i in entregables:
        texto, posicion = entregables[i]
        if isinstance(bloques[0], tuple):
            start = bloques[0][0]
            end = start + bloques[0][1]
        else:
            start = min(bloques)
            end = max(bloques)
        if posicion == "right":
            ax.text(end - 0.1, i, texto, ha='right', va='center',
                    color=label_color, fontsize=10, fontweight='bold')
        else:
            ax.text(start - 0.9, i, texto, ha='left', va='center',
                    color=label_color, fontsize=10, fontweight='bold')

# Ajuste eje Y
ax.set_yticks(range(len(actividades)))
ax.set_yticklabels(actividades, fontsize=12)

# ✅ Eje X: mover etiquetas al inicio del mes
ax.set_xticks([i - 1 for i in range(1, 9)])
ax.set_xticklabels([f"Mes {i}" for i in range(1, 9)], fontsize=12)

ax.set_xlim(0, 8)
ax.set_ylim(-0.5, len(actividades) - 0.5)
ax.invert_yaxis()
ax.xaxis.grid(True, linestyle="--", alpha=0.5)
ax.tick_params(axis='y', length=0)

# Eje X arriba
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Título eje Y
ax.text(-2, -1, "Actividad", fontsize=13, fontweight='bold', ha='left', va='center', transform=ax.transData)

plt.tight_layout()
plt.show()
